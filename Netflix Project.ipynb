# %% [markdown]
# # Netflix Data Science Project

# %%
# First import Pandas
import pandas as pd
rawdata=pd.read_csv('Netflix.csv') # read and import the dataset
rawdata.head() # see first five entires of the dataset
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
rawdata.tail() # to see bottom five entries of the dataset
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country        Release_Date  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# ...

# %%
rawdata.shape # to check no. of raws and columns
# Out:
# (7789, 11)

# %%
rawdata.columns # check all the columns title
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
rawdata.dtypes # check data types of each columns
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
rawdata.info() # check all the information of the dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
rawdata[rawdata.duplicated()] # check the duplicate records in our dataset
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
rawdata.drop_duplicates(inplace=True)  # to remove duplicate records permanently from our dataset

# %%
rawdata.shape # check the duplicated rows has been removed
# Out:
# (7787, 11)

# %%
rawdata.isnull() # see null/missing values in dataset
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description
# 0      False     False  False        False
# ...

# %%
rawdata.isnull().sum() # count all the Naull values in each column
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %%
# now we will see null values by using heatmap from Seaborn library 
import seaborn as sns  # to import seaborn library
sns.heatmap(rawdata.isnull())
# Out:
# <AxesSubplot:>

# %%
rawdata=rawdata.dropna() # to drop all the null values from the data

# %% [markdown]
# # Now we will try to answer the following questions:
# Q1. What is duration of the movie "50 First Dates" and the release date of it?

# %%
rawdata[rawdata['Title'].isin(['50 First Dates'])] # checking the particular recored of the movie
# Out:
#     Show_Id Category           Title     Director  \
# 121    s122    Movie  50 First Dates  Peter Segal
#
#                                                   Cast        Country  \
# 121  Adam Sandler, Drew Barrymore, Rob Schneider, S...  United States
#
#          Release_Date Rating Duration                       Type  \
# 121  December 1, 2020  PG-13   99 min  Comedies, Romantic Movies
#
#                                            Description
# 121  After falling for a pretty art teacher who has...

# %%
# alternative way of checking any particluar string
x=rawdata[rawdata['Title'].str.contains('50 First Dates')]

# %%
x['Duration'] # check duration of the movie
# Out:
# 121    99 min
# Name: Duration, dtype: object

# %%
x['Release_Date'] #check release date of the movie
# Out:
# 121    December 1, 2020
# Name: Release_Date, dtype: object

# %% [markdown]
# Q2. Describe with the 'Pie chart' for the year when the highest number of movies and TV shows were released?

# %%
rawdata['YMovies']=pd.to_datetime(rawdata['Release_Date'])# create a new column Ymovies in our dataset 
rawdata
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
rawdata['YMovies'].dt.year.value_counts() # to count all the years with no. of movie released in YMovies column
# Out:
# 2019    1337
# 2020    1229
# 2018    1115
# 2017     752
# 2016     207
# 2021      78
# 2015      50
# 2014      14
# 2011      13
# 2013       7
# 2012       3
# 2009       2
# 2010       1
# 2008       1
# Name: YMovies, dtype: int64

# %%
rawdata['YMovies'].dt.year.value_counts().plot(kind='pie') # polting pie chart of Ymovies
# Out:
# <AxesSubplot:ylabel='YMovies'>

# %% [markdown]
# Q3. What are the total count of different Ratings in the dataset? Show with bar graph?

# %%
rawdata.groupby('Rating').Rating.count() # grouping and counting all items in a column
# Out:
# Rating
# G             38
# NC-17          2
# NR            62
# PG           238
# PG-13        375
# R            654
# TV-14       1133
# TV-G          80
# TV-MA       1666
# TV-PG        413
# TV-Y          71
# TV-Y7         69
# TV-Y7-FV       3
# UR             5
# Name: Rating, dtype: int64

# %%
sns.countplot(x=rawdata['Rating']) # to plot bar graph for all values of any column
# Out:
# <AxesSubplot:xlabel='Rating', ylabel='count'>

# %% [markdown]
# Q4. Show all the movies released in the year 2011?

# %%
rawdata.head(7) # check again our dataset
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
# 6  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...          Egypt
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
#
#         Release_Date Rating  Duration  \
# ...

# %%
rawdata['Year']=rawdata['YMovies'].dt.year  # to create a new column with years only
rawdata.head() # again checking the data to confirm the new column has been created
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
 # to filter movie from the category and particular year from the year column
rawdata[(rawdata['Category']=='Movie') & (rawdata['Year']==2011)]
# Out:
#      Show_Id Category                                       Title  \
# 232     s233    Movie                  A Stoning in Fulham County
# 308     s309    Movie                    Adam: His Song Continues
# 2041   s2042    Movie                               Even the Rain
# 2622   s2623    Movie                                Hard Lessons
# 2962   s2963    Movie                 In Defense of a Married Man
# 3221   s3222    Movie                      Joseph: King of Dreams
# 5042   s5042    Movie  Quiet Victory: The Charlie Wedemeyer Story
# 5833   s5833    Movie                              Strange Voices
# 6847   s6846    Movie                        The Ryan White Story
# 7151   s7150    Movie                          Too Young the Hero
# 7232   s7231    Movie                        Triumph of the Heart
# 7364   s7363    Movie                            Unspeakable Acts
# 7416   s7415    Movie                            Victim of Beauty
#
#                            Director  \
# ...

# %% [markdown]
# Q5. Show all the titles of the movies that were released in United States only?

# %%
# filtering movies from the category column and specific country from the country column;
rawdata[(rawdata['Category']=='Movie') & (rawdata['Country']=='United States')]
# Out:
#      Show_Id Category                       Title         Director  \
# 3         s4    Movie                           9      Shane Acker
# 4         s5    Movie                          21   Robert Luketic
# 7         s8    Movie                         187   Kevin Reynolds
# 10       s11    Movie                        1922     Zak Hilditch
# 14       s15    Movie                        3022       John Suits
# ...      ...      ...                         ...              ...
# 7760   s7759    Movie  Zack and Miri Make a Porno      Kevin Smith
# 7773   s7772    Movie                        Zion       Floyd Russ
# 7776   s7775    Movie                      Zodiac    David Fincher
# 7780   s7779    Movie                  Zombieland  Ruben Fleischer
# 7783   s7782    Movie                        Zoom     Peter Hewitt
#
#                                                    Cast        Country  \
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# ...

# %%
# to show movies with the Title only
rawdata[(rawdata['Category']=='Movie') & (rawdata['Country']=='United States')]['Title']
# Out:
# 3                                9
# 4                               21
# 7                              187
# 10                            1922
# 14                            3022
#                    ...
# 7760    Zack and Miri Make a Porno
# 7773                          Zion
# 7776                        Zodiac
# 7780                    Zombieland
# 7783                          Zoom
# Name: Title, Length: 1627, dtype: object

# %% [markdown]
# Q6. Find the top five Casts who has the higest numbers of movies in NetFlix?

# %%
rawdata[(rawdata['Category']=='Movie')]['Cast'].value_counts().head() # filters movies and counts casts with no of movies
# Out:
# Samuel West     10
# Jeff Dunham      7
# Kevin Hart       6
# Bill Burr        5
# Jim Gaffigan     5
# Name: Cast, dtype: int64

# %% [markdown]
# Q7. Find all the TV shows with the types are Comdies or released in the country USA?

# %%
rawdata.head() # check our data set again to recall the columns names
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 5  Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...         Turkey
#
#         Release_Date Rating  Duration  \
# 1  December 23, 2016  TV-MA    93 min
# 2  December 20, 2018      R    78 min
# 3  November 16, 2017  PG-13    80 min
# 4    January 1, 2020  PG-13   123 min
# 5       July 1, 2017  TV-MA  1 Season
#
# ...

# %%
# filtering TV Shows based on Comdies
rawdata[(rawdata['Category']=='TV Show') & (rawdata['Type']=='TV Comedies')].tail()
# Out:
#      Show_Id Category                                   Title  \
# 4075   s4076  TV Show                  Middleditch & Schwartz
# 7179   s7178  TV Show  Trailer Park Boys: The Animated Series
#
#                                                Director  \
# 4075                                        Ryan Polito
# 7179  Norm Hiscock, Gary Howsam, Mike Smith, John Pa...
#
#                                                    Cast        Country  \
# 4075                   Thomas Middleditch, Ben Schwartz  United States
# 7179  Mike Smith, John Paul Tremblay, Robb Wells, Jo...         Canada
#
#         Release_Date Rating   Duration         Type  \
# 4075  April 21, 2020  TV-MA   1 Season  TV Comedies
# 7179    May 22, 2020  TV-MA  2 Seasons  TV Comedies
#
#                                             Description    YMovies  Year
# 4075  Comedy duo Thomas Middleditch and Ben Schwartz... 2020-04-21  2020
# 7179  Nova Scotia’s favorite miscreants have always ... 2020-05-22  2020

# %%
# to check Comedy TV Shows or released in United States 
rawdata[((rawdata['Category']=='TV Show') & (rawdata['Type']=='TV Comedies'))|(rawdata['Category']=='TV Show')&(rawdata['Country']=='United States')]
# Out:
#      Show_Id Category                                              Title  \
# 578     s579  TV Show                       Ari Shaffir: Double Negative
# 584     s585  TV Show                                              Arrow
# 1470   s1471  TV Show                   Comedians in Cars Getting Coffee
# 1629   s1630  TV Show                                     Dave Chappelle
# 1630   s1631  TV Show   Dave Chappelle: Equanimity & The Bird Revelation
# 1647   s1648  TV Show                           DC's Legends of Tomorrow
# 1981   s1982  TV Show                         Ellen DeGeneres: Relatable
# 2196   s2197  TV Show                                     Five Came Back
# 2360   s2361  TV Show                      Garth Brooks: The Road I’m On
# 2504   s2505  TV Show                                             Gotham
# 2697   s2698  TV Show                                      Hemlock Grove
# 2832   s2833  TV Show                                     House of Cards
# ...

# %% [markdown]
# Q8. Find the number of movies available in Netflix data where Adam Sandler was a cast?

# %%
rawdata[rawdata['Cast']=='Adam Sandler'] # to find a particular a particular cast
# Out:
#     Show_Id Category                    Title     Director          Cast  \
# 307    s308    Movie  ADAM SANDLER 100% FRESH  Steve Brill  Adam Sandler
#
#            Country      Release_Date Rating Duration             Type  \
# 307  United States  October 23, 2018  TV-MA   74 min  Stand-Up Comedy
#
#                                            Description    YMovies  Year
# 307  From "Heroes" to "Ice Cream Ladies" – Adam San... 2018-10-23  2018

# %%
#alternative of the above command
rawdata[rawdata['Cast'].isin(["Adam Sandler"])]
# Out:
#     Show_Id Category                    Title     Director          Cast  \
# 307    s308    Movie  ADAM SANDLER 100% FRESH  Steve Brill  Adam Sandler
#
#            Country      Release_Date Rating Duration             Type  \
# 307  United States  October 23, 2018  TV-MA   74 min  Stand-Up Comedy
#
#                                            Description    YMovies  Year
# 307  From "Heroes" to "Ice Cream Ladies" – Adam San... 2018-10-23  2018

# %%
# the above results are not 100% correct as it fails to collect the particular cast name written with other casts
# to avoid this and get correct answer, we will use the following codes 
rawdata[rawdata['Cast'].str.contains('Adam Sandler')] # to find particular cast name written with other cast and alone
# Out:
#      Show_Id Category                                      Title  \
# 121     s122    Movie                             50 First Dates
# 307     s308    Movie                    ADAM SANDLER 100% FRESH
# 522     s523    Movie                           Anger Management
# 802     s803    Movie                            Bedtime Stories
# 901     s902    Movie                                  Big Daddy
# 1416   s1417    Movie                                      Click
# 2829   s2830    Movie      Hotel Transylvania 3: Summer Vacation
# 2855   s2856    Movie                            Hubie Halloween
# 3666   s3667    Movie                               Little Nicky
# 4250   s4251    Movie                                  Mr. Deeds
# 4289   s4290    Movie                             Murder Mystery
# 5376   s5376    Movie                               Sandy Wexler
# 6309   s6308    Movie                                The Do-Over
# ...

# %% [markdown]
# Q9. Movies from how many contries are present in Netflix Dataset? What are the country names?

# %%
rawdata['Country'].nunique() # to find the number of unique items present in a column
# Out:
# 544

# %%
rawdata['Country'].unique() # to find unique items names present in a column
# Out:
# array(['Mexico', 'Singapore', 'United States', 'Turkey', 'Egypt', 'India',
#        'Thailand', 'Nigeria', 'Norway, Iceland, United States',
#        'South Korea', 'Italy', 'Indonesia', 'Canada', 'Romania', 'Spain',
#        'Iceland', 'South Africa, Nigeria', 'France',
#        'United States, South Africa', 'Portugal, Spain',
#        'Hong Kong, China, Singapore', 'United States, Germany',
#        'United Kingdom', 'South Africa, China, United States',
#        'Argentina', 'United States, France, Serbia', 'Germany',
#        'Denmark, France, Poland', 'Poland', 'Japan', 'Kenya',
#        'New Zealand, United Kingdom', 'Pakistan', 'Australia',
#        'United States, China', 'China, Hong Kong',
#        'United States, United Kingdom', 'Taiwan',
#        'France, South Korea, Japan', 'United States, Canada',
#        'United Kingdom, United States',
#        'Netherlands, Denmark, South Africa', 'Canada, United States',
# ...

# %% [markdown]
# Q10. How many movies of USA are rated with PG-13?

# %%
rawdata.head(2) # recall the data set again to recall the column names
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating Duration                                 Type  \
# 1  December 23, 2016  TV-MA   93 min         Dramas, International Movies
# 2  December 20, 2018      R   78 min  Horror Movies, International Movies
#
#                                          Description    YMovies  Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018

# %%
y=rawdata[(rawdata['Category']=='Movie') & (rawdata['Rating']=='PG-13') & (rawdata['Country']=='United States')] # filtering movies with PG-13 ratings
y.Rating.str.contains('PG-13').count() # counts the total no of movies with PG-13 rating
# Out:
# 221

# %% [markdown]
# Q11. What is the movie of united states with maximum duration?

# %%
 # first we will split our duration column into two cloumns
rawdata[['NValue','Unit']]=rawdata.Duration.str.split(' ',expand=True)
rawdata
# Out:
#      Show_Id Category       Title           Director  \
# 1         s2    Movie       07:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7780   s7779    Movie  Zombieland    Ruben Fleischer
# 7782   s7781    Movie         Zoo       Shlok Sharma
# 7783   s7782    Movie        Zoom       Peter Hewitt
# 7784   s7783    Movie        Zozo        Josef Fares
# 7785   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    Cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
# Now we will filter the Movies of USA and then find the unique numerical values of duration
z=rawdata[(rawdata.Category=='Movie') & (rawdata.Country=='United States')]
z.NValue.max() # to find max duration movie of USA
# Out:
# '99'

# %% [markdown]
# Q12. Which Country has the highest number of movies?

# %%
m=rawdata[rawdata.Category=='Movie'].Country.value_counts() # check countries with no of movies
m
# Out:
# United States                                                   1627
# India                                                            827
# United Kingdom                                                   155
# Canada                                                           101
# Egypt                                                             87
#                                                                 ...
# Netherlands, Belgium                                               1
# United Kingdom, Denmark, Canada, Croatia                           1
# Thailand, United States                                            1
# United States, South Korea                                         1
# Sweden, Czech Republic, United Kingdom, Denmark, Netherlands       1
# Name: Country, Length: 536, dtype: int64

# %%
m.head(1) # to see the country with higest no of movies
# Out:
# United States    1627
# Name: Country, dtype: int64

# %% [markdown]
# Q13. Rearrange the dataset based on country?

# %%
rawdata.sort_values(by='Country') # sort a data frame based on Country
# Out:
#      Show_Id Category                     Title                Director  \
# 2148   s2149    Movie  Fernando Sanjiao: Hombre  Raúl Campos, Jan Suter
# 3988   s3989    Movie                     Mater        Pablo D'Alo Abba
# 2884   s2885    Movie               Hypersomnia          Gabriel Grieco
# 4746   s4747    Movie         Palermo Hollywood           Eduardo Pinto
# 291     s292    Movie                  Abzurdah           Daniela Goggi
# ...      ...      ...                       ...                     ...
# 1482   s1483    Movie          Conjuring Spirit             Van M. Pham
# 5655   s5655    Movie       Sky Tour: The Movie       Nguyen Thanh Tung
# 939     s940    Movie             Bitcoin Heist                Ham Tran
# 3105   s3106    Movie                   Jackpot           Dustin Nguyen
# 1493   s1494    Movie                  Cook Off         Tomas Brickhill
#
#                                                    Cast    Country  \
# ...

# %%
rawdata.sort_values(by='Country', ascending=False) #  to sort decending order
# Out:
#      Show_Id Category                 Title               Director  \
# 1493   s1494    Movie              Cook Off        Tomas Brickhill
# 2318   s2319    Movie                 Furie            Le Van Kiet
# 5655   s5655    Movie   Sky Tour: The Movie      Nguyen Thanh Tung
# 1482   s1483    Movie      Conjuring Spirit            Van M. Pham
# 3105   s3106    Movie               Jackpot          Dustin Nguyen
# ...      ...      ...                   ...                    ...
# 6252   s6252    Movie  The Crimes That Bind     Sebastián Schindel
# 6923   s6922    Movie         The Tenth Man          Daniel Burman
# 6888   s6887    Movie               The Son     Sebastián Schindel
# 3035   s3036    Movie             Intuition      Alejandro Montiel
# 1167   s1168    Movie       Caida del Cielo  Néstor Sánchez Sotelo
#
#                                                    Cast    Country  \
# 1493  Tendaiishe Chitima, Tendai Nguni, Jesese Mungo...   Zimbabwe
# ...

# %% [markdown]
# # Thank you so much!
